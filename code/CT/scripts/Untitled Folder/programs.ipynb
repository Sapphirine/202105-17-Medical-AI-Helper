# %%
#This code presents the CT scans selection algortihm from https://github.com/mr7495/COVID-CT-Code
import os
import numpy as np
import cv2
import shutil


def find_inds(ch,st): #function to find the indexes of a character in a string
    indexes=[]
    index0=0
    num=0
    while(True):
        if ch in st[num:]:
            index0=st[num:].index(ch)
            indexes.append(index0+num)
            num=num+index0+1
        else:
            break
    return(indexes)


#os.mkdir('/home/gxt/study/CT/selected_TIF/')#path to save the selected TIFF images

original_path = '/home/gxt/study/CT/try'
#original_path = '/home/gxt/study/CT/OriginalImagesTest'
adds={}
for r,d,f in os.walk(original_path): #Take the addresses of the TIFF files for each patient in the dataset
    #print(r)
    #print(d)
    #print(f)
    for file in f:
        #print(file)
        if'.tif' in file:
            full_add=os.path.join(r,file)
            #print(full_add)
            indexes=find_inds('/',full_add)
            #print(indexes)
            index=indexes[-1]
            if full_add[:index+1] not in adds:
                adds[full_add[:index+1]]=[]
            adds[full_add[:index+1]].append(full_add[index+1:])
#print(adds)
selected={}            
for key in adds:
    zero=[]
    names=[]
    count = 0
    for value in adds[key]:
        count = count+1
        names.append(value)
        address=key+value
        pixel=cv2.imread(address,cv2.IMREAD_UNCHANGED ) #read the TIFF file
        sp=pixel[240:340,120:370] #Crop the region
        counted_zero=0
        for i in np.reshape(sp,(sp.shape[0]*sp.shape[1],1)):
            if i<300: #count the number of pixel values in the region less than 300
                counted_zero+=1
        zero.append(counted_zero)
    #print(count)
    min_zero=min(zero)
    max_zero=max(zero)
    threshold=(max_zero-min_zero)/1.5 #Set the threshold
    indices=np.where(np.array(zero)>threshold) #Find the images that have more dark pixels in the region than the calculated threshold
    selected_names=np.array(names)[indices]
    selected[key]=list(selected_names) #Add the selected images of each patient
print(selected)    
count = 0
#Copy the selected images to the new folder
for key in selected:
    indexes=find_inds('/',key)
    for i in range(4):
        globals()['index{}'.format(i+1)]=indexes[i]
    try:
        os.mkdir('selected_TIF/{}'.format(key[index1+1:index2]))
    except:
        pass
    try:
        os.mkdir('selected_TIF/{}/{}'.format(key[index1+1:index2],key[index2+1:index3]))
    except:
        pass 
    try:
        os.mkdir('selected_TIF/{}/{}/{}'.format(key[index1+1:index2],key[index2+1:index3],key[index3+1:index4]))
    except:
        pass 
    for value in selected[key]:
        #print(key)
        address=key+value
        #print(address)
        count = count+1
        new_address='/home/gxt/study/CT/selected_TIF'+address[3:]
        #shutil.copy(address,new_address)

print(count)
# Out:
# {'/home/gxt/study/CT/try/patient1/': ['137covid_patient1_SR_2_IM00015.tif', '137covid_patient1_SR_4_IM00060.tif', '137covid_patient1_SR_4_IM00090.tif', '137covid_patient1_SR_2_IM00019.tif', '137covid_patient1_SR_2_IM00025.tif', '137covid_patient1_SR_4_IM00086.tif', '137covid_patient1_SR_4_IM00113.tif', '137covid_patient1_SR_4_IM00081.tif', '137covid_patient1_SR_4_IM00076.tif', '137covid_patient1_SR_4_IM00089.tif', '137covid_patient1_SR_4_IM00082.tif', '137covid_patient1_SR_3_IM00015.tif', '137covid_patient1_SR_3_IM00014.tif', '137covid_patient1_SR_4_IM00116.tif', '137covid_patient1_SR_4_IM00075.tif', '137covid_patient1_SR_3_IM00017.tif', '137covid_patient1_SR_4_IM00085.tif', '137covid_patient1_SR_4_IM00057.tif', '137covid_patient1_SR_4_IM00117.tif', '137covid_patient1_SR_3_IM00018.tif', '137covid_patient1_SR_4_IM00056.tif', '137covid_patient1_SR_4_IM00084.tif', '137covid_patient1_SR_2_IM00026.tif', '137covid_patient1_SR_2_IM00016.tif', '137covid_patient1_SR_4_IM00115.tif', '137covid_patient1_SR_4_IM00062.tif', '137covid_patient1_SR_4_IM00112.tif', '137covid_patient1_SR_2_IM00024.tif', '137covid_patient1_SR_3_IM00022.tif', '137covid_patient1_SR_4_IM00063.tif', '137covid_patient1_SR_2_IM00022.tif', '137covid_patient1_SR_2_IM00012.tif', '137covid_patient1_SR_4_IM00114.tif', '137covid_patient1_SR_4_IM00120.tif', '137covid_patient1_SR_4_IM00119.tif', '137covid_patient1_SR_4_IM00074.tif', '137covid_patient1_SR_4_IM00111.tif', '137covid_patient1_SR_2_IM00029.tif', '137covid_patient1_SR_3_IM00012.tif', '137covid_patient1_SR_2_IM00017.tif', '137covid_patient1_SR_4_IM00083.tif', '137covid_patient1_SR_2_IM00011.tif', '137covid_patient1_SR_2_IM00018.tif', '137covid_patient1_SR_2_IM00027.tif', '137covid_patient1_SR_2_IM00014.tif', '137covid_patient1_SR_4_IM00061.tif', '137covid_patient1_SR_4_IM00110.tif', '137covid_patient1_SR_3_IM00011.tif', '137covid_patient1_SR_2_IM00020.tif', '137covid_patient1_SR_4_IM00087.tif', '137covid_patient1_SR_4_IM00118.tif', '137covid_patient1_SR_2_IM00023.tif', '137covid_patient1_SR_4_IM00058.tif', '137covid_patient1_SR_3_IM00023.tif', '137covid_patient1_SR_4_IM00059.tif', '137covid_patient1_SR_4_IM00092.tif', '137covid_patient1_SR_3_IM00019.tif', '137covid_patient1_SR_3_IM00013.tif', '137covid_patient1_SR_3_IM00027.tif', '137covid_patient1_SR_2_IM00013.tif', '137covid_patient1_SR_2_IM00010.tif', '137covid_patient1_SR_3_IM00020.tif', '137covid_patient1_SR_4_IM00055.tif', '137covid_patient1_SR_4_IM00088.tif', '137covid_patient1_SR_4_IM00091.tif', '137covid_patient1_SR_2_IM00028.tif', '137covid_patient1_SR_3_IM00024.tif', '137covid_patient1_SR_4_IM00064.tif']}
# 68
